# %%
import tifffile

s = tifffile.imread("../../data/Justina/stack_1.tif")

# %%
s.shape
# Out:
# (480, 2048, 1024)

# %%
type(s[0,0,0])
# Out:
# numpy.uint16

# %%
import numpy as np

# %%
for i in range(s.shape[0]):
    print(np.mean(s[i]))
# Out:
# 106.95107316970825
# 106.65864419937134
# 113.52584409713745
# 114.04697704315186
# 168.7730097770691
# 170.54434251785278
# 240.59953689575195
# 241.30124139785767
# 310.967209815979
# 311.3115005493164
# 1510.8754873275757
# 1511.478596687317
# 111.03616952896118
# 107.086181640625
# 113.37892961502075
# 113.72860956192017
# 167.48356437683105
# 169.1794924736023
# 238.1541223526001
# 238.76247882843018
# 308.1414866447449
# 309.6965494155884
# 1513.5800552368164
# 1501.8416447639465
# 110.9766755104065
# 107.02759408950806
# 113.22207498550415
# 113.56702375411987
# 166.84307956695557
# 168.85195207595825
# 235.95768690109253
# 236.61995840072632
# 305.3942942619324
# 306.26702213287354
# 1479.1822218894958
# 1489.586673259735
# 110.89975118637085
# 106.94868516921997
# 113.08850193023682
# 113.48232316970825
# 166.41862630844116
# 168.23391962051392
# 235.03936433792114
# 235.60701084136963
# 303.20548963546753
# 303.5944414138794
# 1456.841902256012
# 1452.4238138198853
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,10

# %%
plt.imshow(s[0]),
# Out:
# (<matplotlib.image.AxesImage at 0x10c98bc18>,)
